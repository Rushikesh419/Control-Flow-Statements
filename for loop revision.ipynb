# %% [markdown]
# <a href="https://colab.research.google.com/github/Rushikesh419/Control-Flow-Statements/blob/main/for%20loop%20revision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# FOR LOOPS
# 1) 10 even,odd,natural,whole
for i in range(0,11):
    if i%2==0:
        print(i)

#2) integer anf their square first 10
for i in range (1,11):
    print(i,'\t',i*i)

# 3) 10,20,30,40.....300
for i in range(1,31):
    print(i*10,end=' ')

#4) 105,98,91,....7
for i in range(105,6,-7):
    print(i,end=' ')

# 5) first 10 natural in reverse
for i in range(9,-1,-1):
    print(i,end=' ')

# 6) sum of first 10 natural
sum=0
for i in range(0,10):
    sum=sum+i
print(sum)

# 7) sum of 1st 10 even number
sum=0
for i in range(1,21):
    if i%2==0:
        sum=sum+i
print(sum)

# 8) table of number user wanted
n=int(input('enter the number : '))
for i in range(1,11):
    print(n,'x',i,'=',n*i)

# 9) all even number between 2 numbers excluding both:
n1=int(input('enter the number : '))
n2=int(input('enter the number : '))
if n2>n1:
    for i in range (n1+1,n2):
        if i%2==0:
            print(i)
else:
    for i in range (n2+1,n1):
        if i%2==0:
            print(i)

# 10) whether prime or not
n=int(input('enter the number : '))
prime=True
for i in range (2,n):
    if n%i==0:
        prime=False
        break
if prime==True:
    print('it is prime number')
else:
    print('it is not prime')

# 11) sum of digits of number accepted by user
n=input('enter the number : ')
sum=0
for i in (n):
    sum=sum+int(i)
print(sum)

 # OR

n=int(input('enter the number : '))
sum=0
r=0
len=len(str(n))
for i in range (len):
    r=n%10
    sum=sum+r
    n=n//10
print(sum)

# 12) product of digits
n=int(input('enter the number : '))
prod=1
r=0
len=len(str(n))
for i in range (len):
    r=n%10
    prod=prod*r
    n=n//10
print(prod)

# 13) reverse the number
n=input('enter the number : ')
n=n[::-1]
print(n)


#or second method

n=int(input('enter the number : '))
r=0
nrev=0
len=len(str(n))
for i in range (len):
    r=n%10
    nrev=nrev*10+r
    n=n//10
print(nrev)

# 14) number of names of digits you enter
# it is for dictnory

#15) fibonacci series
n=int(input('enter the number : '))
current=0
previous=1
for i in range(n):
    print(current, end=' ')
    previous,current=current,previous+current
# 15) factorial
n=int(input('enter the number : '))
fact=1
if n<0:
    print('please enter positive number : ')
elif n==0:
    print('factorial of 0 is 1')
else:
    for i in range(1, n + 1):
        fact = fact * i
    print(fact)

# 16) armstrong number
n=input('enter the number : ')
p=0
for i in (n):
    p=p+int(i)**3
if int(n)==p:
    print('armstrong number')
else:
    print('it is not')

# 17) 1/1!+1/2!+1/3!...1/n!
n=int(input('enter the number : '))
sum=0
fact=1
for i in range(1,n+1):
    fact=fact*i
    sum=sum+1/(fact)
print(sum)

# 18) 1+1/1!+1/2!+1/3!...1/n!
n=int(input('enter the number : '))
sum=1
fact=1
for i in range(1,n+1):
    fact=fact*i
    sum=sum+1/(fact)
print(sum)

# 19)accept 10 numbers and display its average
s=0
for i in range (10):
    n=int(input('enter the number : '))
    s=s+n
average=s/10
print(average)

# 20) accept 10, largest and smallest
l=[]
for i in range(10):
    n = int(input('enter the number : '))
    l.append(n)
l.sort()
print(f'largest number is',l[-1])
print(f'smallest number is',l[0])

# 21) sum of odd and even number between 2 included
n1=int(input('enter the number : '))
n2=int(input('enter the number : '))
sumeven=0
sumodd=0
if n2>n1:
    for i in range(n1,n2+1):
        if i%2==0:
            sumeven=sumeven+i
        else:
            sumodd=sumodd+i
else:
    for i in range(n2,n1+1):
        if i%2==0:
            sumeven=sumeven+i
        else:
            sumodd=sumodd+i
print(f'sum of even number is {sumeven}')
print(f'sum of odd number is {sumodd}')

# 22) divisible by 13 but not by 3 in 100 to 500
for i in range (100,500):
    if i%13==0 and i%3!=0:
        print(i)

# 23) 2,22,222,...
n=int(input('enter the number : '))
st='2'
for i in range(n):
    print(st,end=',')
    st=st+'2'

# 24) 1,4,9,16,...n**2
n=int(input('enter the number : '))
for i in range(1,n+1):
    print(i**2,end=',')

# 25)1+x/1!+x**2/2!....x**n/n!
n=int(input('enter the number : '))
x=int(input('enter the number : '))
fact=1
sum=1
for i in range(1,n):
    fact=fact*i
    sum=sum+(x**i)/fact
print(sum)

# 26) x+x**2/2+...x**n/n
n=int(input('enter the number : '))
x=int(input('enter the number : '))
sum=0
for i in range(1,n+1):
    sum=x+(2**i)/i
print(sum)

# 27) 1+8+27+...
n=int(input('enter the number : '))
sum=0
for i in range(0,n+1):
    sum=sum+i**3
print(sum)

# 28)1+2+6+24+120+...
n=int(input('enter the number : '))
sum=0
fact=1
for i in range(1,n+1):
    fact=fact*i
    sum=sum+fact
print(sum)

# 29) 1+4-9+16-25...
n=int(input('enter the number : '))
esum=1
osum=0
for i in range(2,n+1):
    if i%2==0:
        esum=esum+i*i
    else:
        osum=osum+i*i
print(esum-osum)

# 30) all chararcter in computer by for loop
str='computer'
for i in str:
    print(i)

# 31) l=[23,45,32,25,46,33,71,90] print only odd number
l=[23,45,32,25,46,33,71,90]
for i in l:
    if i%2!=0:
        print(i)

# 32) to print all the factors
n=int(input('enter the number : '))
for i in range(1,n+1):
    if n%i==0:
        print(i)


# STRINGS
s="Learning python is very good!!!"
n=len(s)
i=0
print('forward direction')
while i<n:
    print(s[i],end='')
    i=i+1

print("\nreverse direction")
i=1
while i<=n:
    print(s[-i],end='')
    i=i+1

s=' data '
a=s.lstrip()
b=s.rstrip()
c=s.strip()
print(a,b,c)
d=s.find('a',1,4)
print(d)

l='my name is rushikesh salunkhe'
u=l.find('rushi',0,19)
print(u)
n=l.index('mw')
print(n)


# to display all the positions of substrings
s=input("Entermainstring:")
subs=input("Entersubstring:")
flag=False
pos=-1
n=len(s)
while True:
  pos=s.find(subs,pos+1,n)
  if pos==-1:
    break
  print("Found at position",pos)
  flag=True
if flag==False:
  print("Not Found")

s='Learning python is very easy'
print(s.upper())
print(s.lower())
print(s.swapcase())
print(s.title())
print(s.capitalize())
print(s.startswith('l'))
print(s.endswith('y'))
print(s.startswith('Learning'))
print(s.endswith('easy'))

#reverse string
s='rushikesh'
rev=s[::-1]
print(rev)

u='rushi'
m=''.join(reversed(u))
print(m)

# program to reverse order of words
n=input('enter the string : ')
l=n.split()
l1=[]
i=len(l)-1
while i>=0:
    l1.append(l[i])
    i=i-1
output=' '.join(l1)
print(output)

# program to remove duplicate character
s=input("EnterSomeString:")
l=[]
for x in s:
  if x not in l:
     l.append(x)
output=''.join(l)
print(output)

# Write a Program to find the Number of Occurrences of each Character present in the given String?
s=input("Enter Some String:")
d={}
for x in s:
  if x in d.keys():
     d[x]=d[x]+1
  else:
     d[x]=1
for k,v in d.items():
   print("{} = {} Times".format(k,v))
